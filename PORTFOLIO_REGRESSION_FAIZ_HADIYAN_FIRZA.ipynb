# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('boston.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  black    506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.duplicated().sum()
# Out:
# 0
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\faiz hadiyan firza\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\faiz hadiyan firza\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\faiz hadiyan firza\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\faiz hadiyan firza\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
# ...

# %% [markdown]
# ### Check which column to be dropped

# %%
# split train test multicollinearity
from sklearn.model_selection import train_test_split

feature1 = df.drop(columns='medv')
target1 = df[['medv']]

feature_df_train1, feature_df_test1, target_df_train1, target_df_test1 = train_test_split(feature1, target1, test_size=0.20, 
                                                                                          random_state=42)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# calculate VIF scores
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif 
from statsmodels.tools.tools import add_constant

X = add_constant(feature_df_train1)

vif_df = pd.DataFrame([vif(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns).reset_index()
vif_df.columns = ['feature','vif_score']
vif_df = vif_df.loc[vif_df.feature!='const']
vif_df
# Out:
#     feature  vif_score
# 1      crim   1.713187
# 2        zn   2.465631
# 3     indus   3.877855
# 4      chas   1.096674
# 5       nox   4.469150
# 6        rm   1.947809
# 7       age   2.989948
# 8       dis   4.168578
# 9       rad   7.658316
# 10      tax   8.943301
# 11  ptratio   1.851448
# 12    black   1.325121
# 13    lstat   2.818045

# %%
# heatmap correlation
df_train1 = pd.concat([feature_df_train1, target_df_train1], axis=1)
corr = df_train1.corr()

plt.figure(figsize=(10,7))
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Delete `rad`, `dis`, `age`
#
# Because when I only delete `rad` only(with correlation >80%), the VIF score after deletion is still >4 in nox feature
#
# So I decide to delete `dis` and `age` too

# %%
# drop redundant features
feature_df_train1 = feature_df_train1.drop(columns=['rad','dis','age'])
feature_df_test1 = feature_df_test1.drop(columns=['rad','dis','age'])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif 
from statsmodels.tools.tools import add_constant

X = add_constant(feature_df_train1)

vif_df = pd.DataFrame([vif(X.values, i) 
               for i in range(X.shape[1])], 
              index=X.columns).reset_index()
vif_df.columns = ['feature','vif_score']
vif_df = vif_df.loc[vif_df.feature!='const']
vif_df
# Out:
#     feature  vif_score
# 1      crim   1.573154
# 2        zn   1.834654
# 3     indus   3.489920
# 4      chas   1.083254
# 5       nox   3.594087
# 6        rm   1.738770
# 7       tax   3.302730
# 8   ptratio   1.749009
# 9     black   1.313289
# 10    lstat   2.546852

# %% [markdown]
# All of the VIF score <4, so it is work

# %% [markdown]
# # Train Test Validation

# %%
# split train test
from sklearn.model_selection import train_test_split

feature = df.drop(columns='medv')
target = df[['medv']]

feature_df_pretrain, feature_df_test, target_df_pretrain, target_df_test = train_test_split(feature, target, 
                                      test_size=0.20, random_state=42)

feature_df_train, feature_df_validation, target_df_train, target_df_validation = train_test_split(feature_df_pretrain, 
                                      target_df_pretrain, test_size=0.20, random_state=42)

# %%
feature_df_train = feature_df_train.drop(columns=['rad','dis','age'])
feature_df_validation = feature_df_validation.drop(columns=['rad','dis','age'])
feature_df_test = feature_df_test.drop(columns=['rad','dis','age'])

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

# train the model
X_df_train = feature_df_train.to_numpy()
y_df_train = target_df_train.to_numpy()
y_df_train = y_df_train.reshape(len(y_df_train))

# define the model
ridge_reg_pointzeroone = Ridge(alpha=0.01, random_state=42)
ridge_reg_pointone = Ridge(alpha=0.1, random_state=42)
ridge_reg_one = Ridge(alpha=1, random_state=42)
ridge_reg_ten = Ridge(alpha=10, random_state=42)

# fit the model (training)
ridge_reg_pointzeroone.fit(X_df_train, y_df_train)
ridge_reg_pointone.fit(X_df_train, y_df_train)
ridge_reg_one.fit(X_df_train, y_df_train)
ridge_reg_ten.fit(X_df_train, y_df_train)
# Out:
# Ridge(alpha=10, random_state=42)

# %%
from sklearn.metrics import mean_squared_error

X_df_validation = feature_df_validation.to_numpy()
y_df_validation = target_df_validation.to_numpy()
y_df_validation = y_df_validation.reshape(len(y_df_validation),)

alphas = [0.01, 0.1, 1., 10]
models = [ridge_reg_pointzeroone,
          ridge_reg_pointone,
          ridge_reg_one,
          ridge_reg_ten]

for model, alpha in zip(models, alphas):
    y_predict_validation = model.predict(X_df_validation)
    rmse = np.sqrt(mean_squared_error(y_df_validation,y_predict_validation))
    print(f'RMSE of Ridge regression model with alpha = {alpha} is {rmse}')
# Out:
# RMSE of Ridge regression model with alpha = 0.01 is 5.098268420074665
# RMSE of Ridge regression model with alpha = 0.1 is 5.095403450801556
# RMSE of Ridge regression model with alpha = 1.0 is 5.080605055050946
# RMSE of Ridge regression model with alpha = 10 is 5.025688234268093

# %% [markdown]
# Use Alpha = 10 because it has the most smallest number of RMSE

# %%
ridge_best = ridge_reg_ten

coef_df = pd.DataFrame({
    'feature':['intercept'] + feature_df_train.columns.tolist(),
    'coefficient':[ridge_best.intercept_] + list(ridge_best.coef_)
})

coef_df
# Out:
#       feature  coefficient
# 0   intercept     7.540114
# 1        crim    -0.048509
# 2          zn    -0.017210
# 3       indus     0.062253
# 4        chas     2.158150
# 5         nox    -0.690866
# 6          rm     5.221478
# 7         tax    -0.000087
# 8     ptratio    -0.881094
# 9       black     0.013078
# 10      lstat    -0.504826

# %% [markdown]
# It means that if every feature given = 0, the target price will be 7.540114,
#
# And every 1 point of the feature below rises (when other features are kept fixed), means:
# - `crim`: decrease 0,048509 of target price
# - `zn`: decrease 0,017210 of target price
# - `indus`: increase 0,062253 of target price
# - `chas`: increase 2,158150 of target price
# - `nox`: decrease 0,690866 of target price
# - `rm`: increase 5,221478 of target price
# - `tax`: decrease 0,000087 of target price
# - `ptratop`: decrease 0,881094 of target price
# - `black`: increase 0.013078 of target price
# - `lstat`: decrease 0,504826 of target price

# %% [markdown]
# ### Lasso

# %%
from sklearn.linear_model import Lasso

# train the model
X_df_train1 = feature_df_train.to_numpy()
y_df_train1 = target_df_train.to_numpy()
y_df_train1 = y_df_train.reshape(len(y_df_train))

# define the model
lasso_reg_pointzeroone = Lasso(alpha=0.01, random_state=42)
lasso_reg_pointone = Lasso(alpha=0.1, random_state=42)
lasso_reg_one = Lasso(alpha=1, random_state=42)
lasso_reg_ten = Lasso(alpha=10, random_state=42)

# fit the model (training)
lasso_reg_pointzeroone.fit(X_df_train1, y_df_train1)
lasso_reg_pointone.fit(X_df_train1, y_df_train1)
lasso_reg_one.fit(X_df_train1, y_df_train1)
lasso_reg_ten.fit(X_df_train1, y_df_train1)
# Out:
# Lasso(alpha=10, random_state=42)

# %%
from sklearn.metrics import mean_squared_error

X_df_validation1 = feature_df_validation.to_numpy()
y_df_validation1 = target_df_validation.to_numpy()
y_df_validation1 = y_df_validation.reshape(len(y_df_validation),)

alphas = [0.01, 0.1, 1., 10]
models = [lasso_reg_pointzeroone,
          lasso_reg_pointone,
          lasso_reg_one,
          lasso_reg_ten]

for model, alpha in zip(models, alphas):
    y_predict_validation1 = model.predict(X_df_validation1)
    rmse = np.sqrt(mean_squared_error(y_df_validation1,y_predict_validation1))
    print(f'RMSE of Lasso regression model with alpha = {alpha} is {rmse}')
# Out:
# RMSE of Lasso regression model with alpha = 0.01 is 5.085135239272938
# RMSE of Lasso regression model with alpha = 0.1 is 5.059655909413482
# RMSE of Lasso regression model with alpha = 1.0 is 4.8846734459521866
# RMSE of Lasso regression model with alpha = 10 is 5.4330815297186374

# %% [markdown]
# Use Alpha = 1

# %%
lasso_best = lasso_reg_one

coef_df1 = pd.DataFrame({
    'feature':['intercept'] + feature_df_train.columns.tolist(),
    'coefficient':[lasso_best.intercept_] + list(lasso_best.coef_)
})

coef_df1
# Out:
#       feature  coefficient
# 0   intercept    22.909724
# 1        crim    -0.028972
# 2          zn    -0.015200
# 3       indus     0.002053
# 4        chas     0.000000
# 5         nox     0.000000
# 6          rm     2.941434
# 7         tax     0.000029
# 8     ptratio    -0.805970
# 9       black     0.011680
# 10      lstat    -0.627903

# %% [markdown]
# It means that if every feature given = 0, the target price will be 22.9097,
#
# And every 1 point of the feature below rises (when other features are kept fixed), means:
# - `crim`: decrease 0,029897 of target price
# - `zn`: decrease 0,0152 of target price
# - `indus`: increase 0,002053 of target price
# - `chas`: eliminated
# - `nox`: elminated
# - `rm`: increase 2,941434 of target price
# - `tax`: increase 0,0000029 of target price
# - `ptratop`: decrease 0,80597 of target price
# - `black`: increase 0.01168 of target price
# - `lstat`: decrease 0,627903 of target price

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### Ridge

# %%
from sklearn.metrics import r2_score

y_predict_train = ridge_best.predict(X_df_train)

print('R-squared for training data is {}'.format(r2_score(y_df_train, y_predict_train)))
# Out:
# R-squared for training data is 0.7276321769842198

# %% [markdown]
# The model can interpret 72,76% of the train data

# %%
# calculate residuals
residual = y_df_train - y_predict_train

# prepare dataframe
# 1 predictor --> predictor VS residual
df_resid = pd.DataFrame({
    'predicted_value': y_predict_train,
    'residual': residual
})

# residual plot
sns.scatterplot(data=df_resid, x="predicted_value", y="residual")
plt.axhline(0)
plt.show()

# %%
# prepare prediction result on training data

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

print('RMSE for training data is {}'.format(np.sqrt(mean_squared_error(y_df_train, y_predict_train))))
print('MAE for training data is {}'.format(mean_absolute_error(y_df_train, y_predict_train)))
print('MAPE for training data is {}'.format(mean_absolute_percentage_error(y_df_train, y_predict_train)))
# Out:
# RMSE for training data is 4.97380593421474
# MAE for training data is 3.5114230940990825
# MAPE for training data is 0.1733167898442232

# %% [markdown]
# The standard deviation of our prediction errors with respect to the regression line in training data is 4,973
#
# The model's prediction in average has an absolute basis difference (MAE) of 3,51142 in training data
#
# The model's prediction in average has an relative percentage basis difference (MAPE) of 17,33% in training data

# %%
# prepare prediction result on test data
X_df_test = feature_df_test.to_numpy()
y_predict_test = ridge_best.predict(X_df_test)

# ground truth target
y_df_test = target_df_test.to_numpy()
y_df_test = y_df_test.reshape(len(y_df_test),)

# %%
print('RMSE for testing data is {}'.format(np.sqrt(mean_squared_error(y_df_test, y_predict_test))))
print('MAE for testing data is {}'.format(mean_absolute_error(y_df_test, y_predict_test)))
print('MAPE for testing data is {}'.format(mean_absolute_percentage_error(y_df_test, y_predict_test)))
# Out:
# RMSE for testing data is 5.480676526334267
# MAE for testing data is 3.4107171499552114
# MAPE for testing data is 0.18309305709162868

# %% [markdown]
# The standard deviation of our prediction errors with respect to the regression line in testing data is 5,4807
#
# The model's prediction in average has an absolute basis difference (MAE) of 3,41071 in testing data
#
# The model's prediction in average has an relative percentage basis difference (MAPE) of 18,3% in testing data

# %% [markdown]
# ### Lasso

# %%
y_predict_train1 = lasso_best.predict(X_df_train1)

print('R-squared for training data is {}'.format(r2_score(y_df_train1, y_predict_train1)))
# Out:
# R-squared for training data is 0.6901461481238917

# %% [markdown]
# The model can interpret 69,01% of the train data

# %%
# calculate residuals
residual = y_df_train1 - y_predict_train1

# prepare dataframe
# 1 predictor --> predictor VS residual
df_resid = pd.DataFrame({
    'predicted_value': y_predict_train1,
    'residual': residual
})

# residual plot
sns.scatterplot(data=df_resid, x="predicted_value", y="residual")
plt.axhline(0)
plt.show()

# %%
print('RMSE for training data is {}'.format(np.sqrt(mean_squared_error(y_df_train1, y_predict_train1))))
print('MAE for training data is {}'.format(mean_absolute_error(y_df_train1, y_predict_train1)))
print('MAPE for training data is {}'.format(mean_absolute_percentage_error(y_df_train1, y_predict_train1)))
# Out:
# RMSE for training data is 5.305048834092741
# MAE for training data is 3.7812526295995066
# MAPE for training data is 0.17632038279736761

# %% [markdown]
# The standard deviation of our prediction errors with respect to the regression line in training data is 5,305
#
# The model's prediction in average has an absolute basis difference (MAE) of 3,7813 in training data
#
# The model's prediction in average has an relative percentage basis difference (MAPE) of 17,63% in training data

# %%
# prepare prediction result on test data
X_df_test1 = feature_df_test.to_numpy()
y_predict_test1 = lasso_best.predict(X_df_test)

# ground truth target
y_df_test1 = target_df_test.to_numpy()
y_df_test1 = y_df_test1.reshape(len(y_df_test),)

# %%
print('RMSE for testing data is {}'.format(np.sqrt(mean_squared_error(y_df_test1, y_predict_test1))))
print('MAE for testing data is {}'.format(mean_absolute_error(y_df_test1, y_predict_test1)))
print('MAPE for testing data is {}'.format(mean_absolute_percentage_error(y_df_test1, y_predict_test1)))
# Out:
# RMSE for testing data is 5.33956016704644
# MAE for testing data is 3.572900527120014
# MAPE for testing data is 0.18399301988769076

# %% [markdown]
# The standard deviation of our prediction errors with respect to the regression line in testing data is 5,3395
#
# The model's prediction in average has an absolute basis difference (MAE) of 3,5729 in testing data
#
# The model's prediction in average has an relative percentage basis difference (MAPE) of 18,4% in testing data

# %% [markdown]
# # Conclusion

# %% [markdown]
# From those modelling with Ridge and Lasso regression, by the RMSE, MAE, MAPE indicator
#
# The Ridge Regression has a slightly smaller error in training data and both just have same error in testing data
#
# But if we see through MAE and MAPE indicator, Ridge is the better model than Lasso
